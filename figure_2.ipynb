# %%
import numpy as np

q = np.arange(100)
q = q/10
d = 10-q
s = q
no_tax = np.full(100, 2.5)
tax = np.full(100,4.5)

# %%
import matplotlib.pyplot as plt

plt.style.use("ggplot")

fig = plt.figure(figsize=(12, 6))

plt.plot(q, d)
plt.plot(q, no_tax) 
plt.plot(q, tax)

plt.fill_between(
    q[55:76],
    no_tax[55:76],      # Pw
    d[55:76],           # кривая D
    color="orange",
    alpha=0.4
)

fig.text(
    0.1,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.505,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "Foreign Supply with Tariff", 
    fontsize=9,             # Keep it small
    color='black',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.1,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.345,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "Foreign Supply without Tariff", 
    fontsize=9,             # Keep it small
    color='black',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.15,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.79,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "Domestic Demand", 
    fontsize=9,             # Keep it small
    rotation =-26,
    color='Red',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.0,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.35,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "p0", 
    fontsize=9,             # Keep it small
    rotation =0,
    color='black',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.0,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.5,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "p1", 
    fontsize=9,             # Keep it small
    rotation =0,
    color='black',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.55,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.06,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "q1", 
    fontsize=9,             # Keep it small
    rotation =0,
    color='black',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.72,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.06,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "q0", 
    fontsize=9,             # Keep it small
    rotation =0,
    color='black',
    ha='left'               # Horizontal alignment
)
fig.text(
    0.58,                   # X-coordinate (0.0 = far left, 1.0 = far right)
    0.38,                   # Y-coordinate (0.0 = bottom, 1.0 = top)
    "DWL", 
    fontsize=11,             # Keep it small
    rotation =0,
    color='black',
    ha='left'               # Horizontal alignment
)


plt.yticks([])
plt.xticks([])

plt.title("")
plt.ylabel("P", loc = "top", rotation = 0)
plt.xlabel("Q", loc = "right")
plt.ticklabel_format(style='plain', axis='y')
fig.tight_layout(rect=[0, 0.03, 1, 1])
plt.show()

plt.show()
